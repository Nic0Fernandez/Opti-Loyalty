# %%
import sqlite3
import pandas as pd
import numpy as np

# %% [markdown]
# Récupération des données

# %%
conn = sqlite3.connect('../../db.sqlite3')

query_pizzas = """
SELECT pizza_id, name, size, ingredients
FROM main_pizza;
"""
pizzas_df = pd.read_sql_query(query_pizzas, conn)

query_orders = """
SELECT client_id, pizza_id, order_date
FROM main_order;
"""
orders_df = pd.read_sql_query(query_orders, conn)
orders_df['order_date'] = pd.to_datetime(orders_df['order_date'])

conn.close()

# %% [markdown]
# Fonction de recommandation

# %%
def get_pizza_ingredients(pizza_id, pizzas_df):
    return pizzas_df[pizzas_df['pizza_id'] == pizza_id]['ingredients'].iloc[0].split(', ')

def recommend_pizzas_based_on_ingredients(client_pizzas, pizzas_df, top_k=1):
    """
    Recommande des pizzas basées sur les ingrédients des pizzas commandées par le client.
    
    Parameters:
        client_pizzas (List[str]): Liste des pizza_ids des pizzas commandées par le client.
        similarity_matrix (array): Matrice de similarité entre les pizzas.
        pizzas_df (DataFrame): Informations sur les pizzas.
        top_k (int): Nombre de recommandations.
    
    Returns:
        List[Tuple[str, float]]: Liste des recommandations avec scores.
    """
    # Extraire les ingrédients des pizzas commandées par le client
    client_ingredients = []
    for pizza_id in client_pizzas:
        client_ingredients.extend(get_pizza_ingredients(pizza_id, pizzas_df))
    client_ingredients = set(client_ingredients)  # Éviter les doublons
    
    # Calculer la similarité avec les autres pizzas basées sur les ingrédients partagés
    similarities = []
    for idx, pizza in pizzas_df.iterrows():
        pizza_ingredients = set(pizza['ingredients'].split(', '))
        common_ingredients = len(client_ingredients.intersection(pizza_ingredients))
        total_ingredients = len(client_ingredients.union(pizza_ingredients))
        similarity_score = common_ingredients / total_ingredients if total_ingredients > 0 else 0
        similarities.append((pizza['pizza_id'], similarity_score))
    
    # Trier les pizzas par similarité décroissante et retourner les k premières
    recommendations = sorted(similarities, key=lambda x: x[1], reverse=True)[:top_k]
    recommended_pizzas = [pizza[0] for pizza in recommendations]
    
    return recommended_pizzas

# %% [markdown]
# Évaluation des performances

# %%
def precision_recall_at_k(recommended_pizzas, relevant_pizzas, k=1):
    recommended_set = set(recommended_pizzas[:k])  
    relevant_set = set(relevant_pizzas)  # Pizzas réellement commandées
    hits = recommended_set.intersection(relevant_set)
    
    precision = len(hits) / k
    recall = len(hits) / len(relevant_set) if len(relevant_set) > 0 else 0
    return precision, recall

clients = orders_df['client_id'].unique()

precisions, recalls, f1_scores = [], [], []

for client_id in clients:
    relevant_pizzas = orders_df[orders_df['client_id'] == client_id]['pizza_id'].tolist()
    relevant_pizzas = pizzas_df[pizzas_df['pizza_id'].isin(relevant_pizzas)]['name'].tolist()
    
    client_pizzas = orders_df[orders_df['client_id'] == client_id]['pizza_id'].tolist()
    
    # Recommandations basées sur ingrédients
    recommended_pizzas = recommend_pizzas_based_on_ingredients(client_pizzas, pizzas_df, top_k=1)
    recommended_pizzas_names = pizzas_df[pizzas_df['pizza_id'].isin(recommended_pizzas)]['name'].tolist()
    
    print(f"Client {client_id} :")
    print(f"Recommandations : {recommended_pizzas_names}")
    print(f"Pizzas pertinentes : {relevant_pizzas}")
    
    precision, recall = precision_recall_at_k(recommended_pizzas_names, relevant_pizzas, k=1)
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1_score)

print(f"Précision moyenne : {sum(precisions)/len(precisions):.2f}")
print(f"Rappel moyen : {sum(recalls)/len(recalls):.2f}")
print(f"F1-Score moyen : {sum(f1_scores)/len(f1_scores):.2f}")
# Out:
# Client 1 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Spinach Pesto Pizza', 'The Spinach Supreme Pizza', 'The Greek Pizza', 'The Hawaiian Pizza', 'The Spinach and Feta Pizza', 'The Classic Deluxe Pizza', 'The Mexicana Pizza']
# Client 2 :
# Recommandations : ['The Greek Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Greek Pizza', 'The Brie Carre Pizza', 'The Greek Pizza', 'The Greek Pizza', 'The Five Cheese Pizza']
# Client 3 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Greek Pizza', 'The Hawaiian Pizza', 'The Thai Chicken Pizza', 'The Mediterranean Pizza', 'The Pepper Salami Pizza']
# Client 4 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Spicy Italian Pizza', 'The Calabrese Pizza', 'The Pepperoni Pizza', 'The Vegetables + Vegetables Pizza', 'The Spinach and Feta Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The California Chicken Pizza', 'The Five Cheese Pizza', 'The Classic Deluxe Pizza', 'The Pepperoni Pizza', 'The Southwest Chicken Pizza']
# Client 5 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Southwest Chicken Pizza', 'The Napolitana Pizza', 'The Napolitana Pizza', 'The Southwest Chicken Pizza']
# Client 6 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The California Chicken Pizza', 'The Five Cheese Pizza', 'The California Chicken Pizza', 'The California Chicken Pizza']
# Client 7 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Pepper Salami Pizza', 'The Spinach and Feta Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepper Salami Pizza', 'The Classic Deluxe Pizza', 'The Big Meat Pizza', 'The Italian Supreme Pizza', 'The Pepper Salami Pizza', 'The Southwest Chicken Pizza', 'The Mexicana Pizza']
# Client 8 :
# Recommandations : ['The Italian Supreme Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Napolitana Pizza', 'The Hawaiian Pizza', 'The Five Cheese Pizza', 'The Big Meat Pizza', 'The Soppressata Pizza', 'The Italian Supreme Pizza', 'The Pepper Salami Pizza']
# Client 9 :
# Recommandations : ['The Mediterranean Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Mediterranean Pizza', 'The Spicy Italian Pizza']
# Client 10 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Mexicana Pizza', 'The Spicy Italian Pizza', 'The Hawaiian Pizza', 'The Brie Carre Pizza', 'The Greek Pizza', 'The Italian Capocollo Pizza']
# Client 11 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Soppressata Pizza', 'The Pepper Salami Pizza', 'The California Chicken Pizza', 'The Napolitana Pizza']
# Client 12 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Spinach Supreme Pizza', 'The Italian Vegetables Pizza']
# Client 13 :
# Recommandations : ['The Calabrese Pizza']
# Pizzas pertinentes : ['The Calabrese Pizza', 'The Spinach and Feta Pizza', 'The Chicken Pesto Pizza', 'The Four Cheese Pizza']
# Client 14 :
# Recommandations : ['The Spinach Pesto Pizza']
# Pizzas pertinentes : ['The Spinach Pesto Pizza', 'The Spinach and Feta Pizza']
# Client 15 :
# Recommandations : ['The Pepperoni, Mushroom, and Peppers Pizza']
# Pizzas pertinentes : ['The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza']
# Client 16 :
# Recommandations : ['The Four Cheese Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Pepperoni Pizza', 'The Four Cheese Pizza']
# Client 17 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Classic Deluxe Pizza']
# Client 18 :
# Recommandations : ['The Mediterranean Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Mediterranean Pizza', 'The Greek Pizza', 'The Calabrese Pizza', 'The Greek Pizza']
# Client 19 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Spinach and Feta Pizza', 'The Vegetables + Vegetables Pizza', 'The Spinach and Feta Pizza', 'The Spinach and Feta Pizza']
# Client 20 :
# Recommandations : ['The Sicilian Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Big Meat Pizza']
# Client 21 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Thai Chicken Pizza', 'The Spinach and Feta Pizza', 'The California Chicken Pizza', 'The Five Cheese Pizza', 'The Classic Deluxe Pizza', 'The Italian Supreme Pizza']
# Client 22 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Vegetables + Vegetables Pizza', 'The Vegetables + Vegetables Pizza', 'The Prosciutto and Arugula Pizza', 'The Four Cheese Pizza']
# Client 23 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Spicy Italian Pizza', 'The Calabrese Pizza', 'The California Chicken Pizza', 'The California Chicken Pizza']
# Client 24 :
# Recommandations : ['The Spicy Italian Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Spicy Italian Pizza']
# Client 25 :
# Recommandations : ['The Sicilian Pizza']
# Pizzas pertinentes : ['The Napolitana Pizza', 'The Spinach Pesto Pizza', 'The Sicilian Pizza', 'The Italian Capocollo Pizza', 'The Barbecue Chicken Pizza']
# Client 26 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Spinach Pesto Pizza', 'The Chicken Pesto Pizza', 'The Sicilian Pizza', 'The Mexicana Pizza', 'The Barbecue Chicken Pizza', 'The Barbecue Chicken Pizza']
# Client 27 :
# Recommandations : ['The Italian Capocollo Pizza']
# Pizzas pertinentes : ['The Italian Capocollo Pizza']
# Client 28 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Southwest Chicken Pizza', 'The Napolitana Pizza', 'The Hawaiian Pizza', 'The Pepper Salami Pizza', 'The Southwest Chicken Pizza', 'The Four Cheese Pizza', 'The Napolitana Pizza']
# Client 29 :
# Recommandations : ['The Sicilian Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Soppressata Pizza', 'The Sicilian Pizza', 'The Spinach and Feta Pizza', 'The Spinach and Feta Pizza']
# Client 30 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Spinach Pesto Pizza', 'The Pepperoni Pizza', 'The Vegetables + Vegetables Pizza', 'The Vegetables + Vegetables Pizza']
# Client 31 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Vegetables + Vegetables Pizza', 'The Vegetables + Vegetables Pizza', 'The Pepper Salami Pizza', 'The Pepper Salami Pizza']
# Client 32 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Prosciutto and Arugula Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The California Chicken Pizza', 'The Pepperoni Pizza', 'The Spicy Italian Pizza', 'The Classic Deluxe Pizza', 'The Big Meat Pizza', 'The Southwest Chicken Pizza']
# Client 33 :
# Recommandations : ['The Thai Chicken Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Big Meat Pizza']
# Client 34 :
# Recommandations : ['The Italian Vegetables Pizza']
# Pizzas pertinentes : ['The Italian Vegetables Pizza', 'The Pepper Salami Pizza']
# Client 35 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Southwest Chicken Pizza', 'The Hawaiian Pizza', 'The Pepperoni Pizza', 'The California Chicken Pizza', 'The Classic Deluxe Pizza', 'The Southwest Chicken Pizza', 'The Napolitana Pizza', 'The Barbecue Chicken Pizza']
# Client 36 :
# Recommandations : ['The Classic Deluxe Pizza']
# Pizzas pertinentes : ['The Classic Deluxe Pizza', 'The Big Meat Pizza']
# Client 37 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Southwest Chicken Pizza', 'The Pepper Salami Pizza', 'The Southwest Chicken Pizza']
# Client 38 :
# Recommandations : ['The Thai Chicken Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Pepperoni Pizza']
# Client 39 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Green Garden Pizza', 'The Spinach Supreme Pizza', 'The Mexicana Pizza']
# Client 40 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Italian Vegetables Pizza', 'The Spicy Italian Pizza', 'The Spinach and Feta Pizza', 'The Sicilian Pizza', 'The Vegetables + Vegetables Pizza', 'The Italian Supreme Pizza']
# Client 41 :
# Recommandations : ['The Italian Vegetables Pizza']
# Pizzas pertinentes : ['The Italian Vegetables Pizza', 'The Napolitana Pizza', 'The Hawaiian Pizza', 'The Italian Supreme Pizza', 'The Five Cheese Pizza', 'The Classic Deluxe Pizza', 'The Big Meat Pizza', 'The California Chicken Pizza', 'The Four Cheese Pizza']
# Client 42 :
# Recommandations : ['The Mediterranean Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Mediterranean Pizza', 'The Prosciutto and Arugula Pizza', 'The Thai Chicken Pizza', 'The California Chicken Pizza', 'The Chicken Pesto Pizza', 'The California Chicken Pizza']
# Client 43 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Mexicana Pizza', 'The Thai Chicken Pizza', 'The Green Garden Pizza', 'The Mexicana Pizza']
# Client 44 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Mexicana Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza', 'The Mexicana Pizza']
# Client 45 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Pepper Salami Pizza']
# Client 46 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Soppressata Pizza', 'The Italian Capocollo Pizza', 'The Mexicana Pizza', 'The Mexicana Pizza']
# Client 47 :
# Recommandations : ['The Sicilian Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Pepperoni Pizza', 'The Sicilian Pizza', 'The Pepperoni Pizza']
# Client 48 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Southwest Chicken Pizza', 'The Hawaiian Pizza', 'The Sicilian Pizza', 'The Italian Supreme Pizza', 'The Four Cheese Pizza', 'The Italian Supreme Pizza', 'The Napolitana Pizza']
# Client 49 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Chicken Alfredo Pizza', 'The Spinach Pesto Pizza', 'The Soppressata Pizza', 'The Spinach Pesto Pizza', 'The Sicilian Pizza', 'The Italian Capocollo Pizza', 'The Big Meat Pizza', 'The California Chicken Pizza']
# Client 50 :
# Recommandations : ['The Spicy Italian Pizza']
# Pizzas pertinentes : ['The Spicy Italian Pizza']
# Client 51 :
# Recommandations : ['The Green Garden Pizza']
# Pizzas pertinentes : ['The Napolitana Pizza', 'The Spinach and Feta Pizza', 'The Big Meat Pizza']
# Client 52 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Thai Chicken Pizza', 'The Mexicana Pizza']
# Client 53 :
# Recommandations : ['The Mediterranean Pizza']
# Pizzas pertinentes : ['The Pepperoni, Mushroom, and Peppers Pizza', 'The Mediterranean Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza']
# Client 54 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Napolitana Pizza', 'The Pepper Salami Pizza', 'The Vegetables + Vegetables Pizza', 'The California Chicken Pizza', 'The Five Cheese Pizza', 'The Pepperoni Pizza', 'The Big Meat Pizza']
# Client 55 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Mediterranean Pizza', 'The Thai Chicken Pizza', 'The Mediterranean Pizza', 'The Spinach and Feta Pizza', 'The California Chicken Pizza', 'The Mexicana Pizza', 'The Four Cheese Pizza', 'The Four Cheese Pizza']
# Client 56 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Chicken Alfredo Pizza', 'The Southwest Chicken Pizza', 'The Spicy Italian Pizza', 'The Southwest Chicken Pizza', 'The Thai Chicken Pizza', 'The Spinach and Feta Pizza', 'The Big Meat Pizza']
# Client 57 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza', 'The California Chicken Pizza']
# Client 58 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Barbecue Chicken Pizza', 'The Pepper Salami Pizza', 'The Barbecue Chicken Pizza']
# Client 59 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Southwest Chicken Pizza', 'The Spinach Pesto Pizza', 'The Spinach Pesto Pizza', 'The Thai Chicken Pizza', 'The Spinach Pesto Pizza']
# Client 60 :
# Recommandations : ['The Sicilian Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Thai Chicken Pizza', 'The Sicilian Pizza', 'The Sicilian Pizza', 'The Thai Chicken Pizza', 'The Five Cheese Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza', 'The Classic Deluxe Pizza']
# Client 61 :
# Recommandations : ['The Mediterranean Pizza']
# Pizzas pertinentes : ['The Spinach and Feta Pizza', 'The Mediterranean Pizza', 'The Mediterranean Pizza', 'The Spinach and Feta Pizza', 'The Spinach and Feta Pizza']
# Client 62 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Chicken Pesto Pizza', 'The Sicilian Pizza', 'The Spinach and Feta Pizza', 'The Italian Vegetables Pizza', 'The Spinach and Feta Pizza', 'The Mexicana Pizza']
# Client 63 :
# Recommandations : ['The Greek Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Greek Pizza', 'The Sicilian Pizza']
# Client 64 :
# Recommandations : ['The Sicilian Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Green Garden Pizza', 'The Spicy Italian Pizza']
# Client 65 :
# Recommandations : ['The Mediterranean Pizza']
# Pizzas pertinentes : ['The Chicken Alfredo Pizza', 'The Chicken Pesto Pizza', 'The Mediterranean Pizza', 'The Brie Carre Pizza', 'The Spinach Pesto Pizza', 'The Green Garden Pizza', 'The Spicy Italian Pizza', 'The Calabrese Pizza', 'The Spinach Pesto Pizza']
# Client 66 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Italian Capocollo Pizza', 'The Thai Chicken Pizza', 'The Italian Capocollo Pizza', 'The Vegetables + Vegetables Pizza', 'The Calabrese Pizza', 'The Pepperoni Pizza', 'The Big Meat Pizza', 'The Barbecue Chicken Pizza', 'The Four Cheese Pizza']
# Client 67 :
# Recommandations : ['The Pepperoni, Mushroom, and Peppers Pizza']
# Pizzas pertinentes : ['The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni Pizza']
# Client 68 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Napolitana Pizza', 'The Thai Chicken Pizza', 'The Pepperoni Pizza', 'The Sicilian Pizza', 'The Thai Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Five Cheese Pizza', 'The Classic Deluxe Pizza', 'The Southwest Chicken Pizza']
# Client 69 :
# Recommandations : ['The Calabrese Pizza']
# Pizzas pertinentes : ['The Calabrese Pizza', 'The Spicy Italian Pizza', 'The Napolitana Pizza', 'The Barbecue Chicken Pizza', 'The Italian Supreme Pizza', 'The Pepperoni Pizza', 'The Classic Deluxe Pizza']
# Client 70 :
# Recommandations : ['The Four Cheese Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Prosciutto and Arugula Pizza', 'The Four Cheese Pizza']
# Client 71 :
# Recommandations : ['The Greek Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Napolitana Pizza', 'The Greek Pizza', 'The Pepperoni Pizza', 'The Big Meat Pizza']
# Client 72 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Chicken Alfredo Pizza', 'The Napolitana Pizza', 'The Thai Chicken Pizza', 'The Pepper Salami Pizza', 'The Five Cheese Pizza', 'The Pepperoni Pizza', 'The Barbecue Chicken Pizza', 'The Four Cheese Pizza']
# Client 73 :
# Recommandations : ['The Mediterranean Pizza']
# Pizzas pertinentes : ['The Mediterranean Pizza', 'The Spinach Pesto Pizza', 'The Italian Supreme Pizza', 'The Spinach Pesto Pizza']
# Client 74 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Spinach and Feta Pizza', 'The Pepper Salami Pizza', 'The Classic Deluxe Pizza', 'The Pepperoni Pizza', 'The Spinach Pesto Pizza', 'The Pepper Salami Pizza', 'The Four Cheese Pizza', 'The Mexicana Pizza']
# Client 75 :
# Recommandations : ['The Big Meat Pizza']
# Pizzas pertinentes : ['The Big Meat Pizza']
# Client 76 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Pepperoni, Mushroom, and Peppers Pizza', 'The Hawaiian Pizza', 'The Italian Capocollo Pizza', 'The Big Meat Pizza', 'The California Chicken Pizza', 'The Barbecue Chicken Pizza', 'The Italian Supreme Pizza', 'The Chicken Alfredo Pizza', 'The Four Cheese Pizza']
# Client 77 :
# Recommandations : ['The Thai Chicken Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Thai Chicken Pizza', 'The Thai Chicken Pizza']
# Client 78 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Chicken Pesto Pizza', 'The Barbecue Chicken Pizza', 'The California Chicken Pizza', 'The Barbecue Chicken Pizza']
# Client 79 :
# Recommandations : ['The Italian Capocollo Pizza']
# Pizzas pertinentes : ['The Green Garden Pizza', 'The Green Garden Pizza', 'The Italian Capocollo Pizza', 'The Green Garden Pizza', 'The Napolitana Pizza']
# Client 80 :
# Recommandations : ['The Classic Deluxe Pizza']
# Pizzas pertinentes : ['The Pepperoni Pizza', 'The Classic Deluxe Pizza']
# Client 81 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Calabrese Pizza', 'The Brie Carre Pizza', 'The Vegetables + Vegetables Pizza', 'The Vegetables + Vegetables Pizza']
# Client 82 :
# Recommandations : ['The Chicken Pesto Pizza']
# Pizzas pertinentes : ['The Spinach Pesto Pizza', 'The Napolitana Pizza', 'The Thai Chicken Pizza', 'The Hawaiian Pizza', 'The Italian Capocollo Pizza', 'The Spinach Pesto Pizza', 'The Spinach and Feta Pizza', 'The Italian Supreme Pizza']
# Client 83 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Spinach Pesto Pizza', 'The Prosciutto and Arugula Pizza', 'The Soppressata Pizza', 'The Spinach Pesto Pizza', 'The Vegetables + Vegetables Pizza', 'The Hawaiian Pizza', 'The Pepperoni Pizza', 'The Southwest Chicken Pizza']
# Client 84 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Pesto Pizza', 'The Spinach and Feta Pizza', 'The Pepper Salami Pizza']
# Client 85 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Vegetables + Vegetables Pizza', 'The Vegetables + Vegetables Pizza', 'The Five Cheese Pizza']
# Client 86 :
# Recommandations : ['The Chicken Pesto Pizza']
# Pizzas pertinentes : ['The Soppressata Pizza', 'The Chicken Pesto Pizza', 'The Four Cheese Pizza', 'The Four Cheese Pizza']
# Client 87 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Italian Capocollo Pizza', 'The Italian Supreme Pizza', 'The Calabrese Pizza', 'The California Chicken Pizza', 'The Italian Supreme Pizza', 'The Four Cheese Pizza']
# Client 88 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Southwest Chicken Pizza', 'The Pepperoni Pizza', 'The Vegetables + Vegetables Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza', 'The Big Meat Pizza']
# Client 89 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Italian Vegetables Pizza', 'The Mexicana Pizza', 'The Chicken Pesto Pizza', 'The Five Cheese Pizza']
# Client 90 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Spinach Supreme Pizza', 'The Sicilian Pizza', 'The Italian Capocollo Pizza', 'The Pepperoni Pizza', 'The California Chicken Pizza', 'The Pepperoni Pizza']
# Client 91 :
# Recommandations : ['The Five Cheese Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Hawaiian Pizza', 'The Hawaiian Pizza', 'The Five Cheese Pizza', 'The Four Cheese Pizza']
# Client 92 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Chicken Pesto Pizza', 'The Southwest Chicken Pizza', 'The Calabrese Pizza', 'The Sicilian Pizza', 'The Italian Vegetables Pizza', 'The Chicken Pesto Pizza', 'The Barbecue Chicken Pizza', 'The Italian Supreme Pizza']
# Client 93 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Pepperoni, Mushroom, and Peppers Pizza', 'The California Chicken Pizza', 'The California Chicken Pizza', 'The California Chicken Pizza']
# Client 94 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Spinach Supreme Pizza', 'The Napolitana Pizza']
# Client 95 :
# Recommandations : ['The Napolitana Pizza']
# Pizzas pertinentes : ['The Napolitana Pizza', 'The Big Meat Pizza', 'The Napolitana Pizza']
# Client 96 :
# Recommandations : ['The Spicy Italian Pizza']
# Pizzas pertinentes : ['The Spicy Italian Pizza', 'The Spinach Pesto Pizza']
# Client 97 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Brie Carre Pizza', 'The Napolitana Pizza', 'The Sicilian Pizza', 'The Thai Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Four Cheese Pizza']
# Client 98 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Chicken Pesto Pizza', 'The Chicken Pesto Pizza', 'The Napolitana Pizza', 'The Chicken Pesto Pizza', 'The Southwest Chicken Pizza']
# Client 99 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Barbecue Chicken Pizza', 'The California Chicken Pizza', 'The California Chicken Pizza', 'The Barbecue Chicken Pizza']
# Client 100 :
# Recommandations : ['The Classic Deluxe Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Classic Deluxe Pizza', 'The Classic Deluxe Pizza']
# Client 101 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Calabrese Pizza', 'The California Chicken Pizza']
# Client 102 :
# Recommandations : ['The Greek Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Pepper Salami Pizza', 'The Greek Pizza', 'The Pepper Salami Pizza']
# Client 103 :
# Recommandations : ['The Italian Supreme Pizza']
# Pizzas pertinentes : ['The Napolitana Pizza', 'The Italian Supreme Pizza', 'The Classic Deluxe Pizza', 'The Napolitana Pizza']
# Client 104 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Hawaiian Pizza', 'The Hawaiian Pizza', 'The Spicy Italian Pizza']
# Client 105 :
# Recommandations : ['The Greek Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Soppressata Pizza', 'The Spinach and Feta Pizza', 'The Napolitana Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza']
# Client 106 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Sicilian Pizza', 'The Sicilian Pizza', 'The Barbecue Chicken Pizza', 'The Pepper Salami Pizza', 'The Classic Deluxe Pizza', 'The Four Cheese Pizza', 'The California Chicken Pizza']
# Client 107 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Calabrese Pizza', 'The Spicy Italian Pizza', 'The Calabrese Pizza', 'The Thai Chicken Pizza', 'The Pepper Salami Pizza', 'The Classic Deluxe Pizza', 'The Spinach Pesto Pizza', 'The Big Meat Pizza', 'The Italian Supreme Pizza', 'The Chicken Alfredo Pizza', 'The Mexicana Pizza']
# Client 108 :
# Recommandations : ['The Spicy Italian Pizza']
# Pizzas pertinentes : ['The Green Garden Pizza', 'The Green Garden Pizza', 'The Spicy Italian Pizza']
# Client 109 :
# Recommandations : ['The Sicilian Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Italian Supreme Pizza', 'The Thai Chicken Pizza', 'The Sicilian Pizza']
# Client 110 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Italian Capocollo Pizza', 'The Italian Capocollo Pizza', 'The Four Cheese Pizza', 'The Four Cheese Pizza', 'The Mexicana Pizza']
# Client 111 :
# Recommandations : ['The Big Meat Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Big Meat Pizza']
# Client 112 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Napolitana Pizza', 'The Greek Pizza', 'The Spinach Supreme Pizza', 'The Five Cheese Pizza']
# Client 113 :
# Recommandations : ['The Chicken Alfredo Pizza']
# Pizzas pertinentes : ['The Chicken Alfredo Pizza', 'The Napolitana Pizza', 'The Napolitana Pizza', 'The Napolitana Pizza']
# Client 114 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Calabrese Pizza', 'The Sicilian Pizza', 'The Pepperoni Pizza', 'The Hawaiian Pizza', 'The Italian Vegetables Pizza', 'The Five Cheese Pizza', 'The Calabrese Pizza', 'The Mexicana Pizza']
# Client 115 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Southwest Chicken Pizza', 'The Sicilian Pizza', 'The Vegetables + Vegetables Pizza', 'The Sicilian Pizza', 'The Southwest Chicken Pizza']
# Client 116 :
# Recommandations : ['The Spinach and Feta Pizza']
# Pizzas pertinentes : ['The Spinach and Feta Pizza', 'The Spinach and Feta Pizza', 'The Spinach and Feta Pizza']
# Client 117 :
# Recommandations : ['The Pepper Salami Pizza']
# Pizzas pertinentes : ['The Pepper Salami Pizza', 'The Barbecue Chicken Pizza', 'The Pepper Salami Pizza', 'The Barbecue Chicken Pizza']
# Client 118 :
# Recommandations : ['The Hawaiian Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza']
# Client 119 :
# Recommandations : ['The Sicilian Pizza']
# Pizzas pertinentes : ['The Spinach Pesto Pizza', 'The Sicilian Pizza', 'The Italian Capocollo Pizza', 'The Spinach and Feta Pizza', 'The Green Garden Pizza', 'The Five Cheese Pizza', 'The Spicy Italian Pizza', 'The Four Cheese Pizza']
# Client 120 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Spicy Italian Pizza', 'The Spicy Italian Pizza', 'The Thai Chicken Pizza', 'The Spicy Italian Pizza', 'The California Chicken Pizza', 'The California Chicken Pizza', 'The Italian Supreme Pizza', 'The Chicken Alfredo Pizza']
# Client 121 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Mexicana Pizza', 'The Southwest Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Vegetables + Vegetables Pizza', 'The Pepper Salami Pizza', 'The Five Cheese Pizza', 'The Pepperoni Pizza', 'The Four Cheese Pizza']
# Client 122 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Pepper Salami Pizza', 'The Italian Capocollo Pizza', 'The Pepper Salami Pizza', 'The Mexicana Pizza']
# Client 123 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Soppressata Pizza', 'The Spicy Italian Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Spinach Supreme Pizza', 'The Barbecue Chicken Pizza', 'The Spicy Italian Pizza', 'The Calabrese Pizza', 'The California Chicken Pizza', 'The Soppressata Pizza', 'The Southwest Chicken Pizza']
# Client 124 :
# Recommandations : ['The Spicy Italian Pizza']
# Pizzas pertinentes : ['The Spicy Italian Pizza']
# Client 125 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Classic Deluxe Pizza', 'The Vegetables + Vegetables Pizza', 'The Hawaiian Pizza', 'The Italian Vegetables Pizza', 'The Italian Supreme Pizza', 'The Prosciutto and Arugula Pizza', 'The Italian Capocollo Pizza', 'The Spicy Italian Pizza']
# Client 126 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Spicy Italian Pizza', 'The Classic Deluxe Pizza', 'The Italian Supreme Pizza', 'The Vegetables + Vegetables Pizza', 'The Five Cheese Pizza', 'The Spicy Italian Pizza', 'The Big Meat Pizza']
# Client 127 :
# Recommandations : ['The Greek Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Greek Pizza', 'The Hawaiian Pizza', 'The Hawaiian Pizza']
# Client 128 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Southwest Chicken Pizza', 'The Italian Capocollo Pizza', 'The Italian Capocollo Pizza', 'The Mediterranean Pizza', 'The Barbecue Chicken Pizza']
# Client 129 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Pepperoni Pizza', 'The Barbecue Chicken Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza']
# Client 130 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Southwest Chicken Pizza', 'The Napolitana Pizza', 'The Pepper Salami Pizza']
# Client 131 :
# Recommandations : ['The Greek Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Barbecue Chicken Pizza']
# Client 132 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Vegetables + Vegetables Pizza', 'The Hawaiian Pizza', 'The Vegetables + Vegetables Pizza']
# Client 133 :
# Recommandations : ['The Spinach Pesto Pizza']
# Pizzas pertinentes : ['The Spinach Pesto Pizza', 'The Spinach Pesto Pizza', 'The Big Meat Pizza']
# Client 134 :
# Recommandations : ['The Mediterranean Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Mediterranean Pizza', 'The Classic Deluxe Pizza', 'The Spinach and Feta Pizza', 'The Hawaiian Pizza', 'The Barbecue Chicken Pizza', 'The California Chicken Pizza', 'The Four Cheese Pizza']
# Client 135 :
# Recommandations : ['The Greek Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Pepper Salami Pizza', 'The Pepper Salami Pizza']
# Client 136 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Italian Supreme Pizza', 'The Thai Chicken Pizza', 'The Thai Chicken Pizza', 'The Greek Pizza', 'The Pepperoni Pizza', 'The Hawaiian Pizza', 'The Spinach and Feta Pizza', 'The Spinach and Feta Pizza', 'The California Chicken Pizza', 'The Four Cheese Pizza', 'The Napolitana Pizza']
# Client 137 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Chicken Pesto Pizza', 'The Spinach Pesto Pizza', 'The Spinach and Feta Pizza', 'The Pepper Salami Pizza']
# Client 138 :
# Recommandations : ['The Spicy Italian Pizza']
# Pizzas pertinentes : ['The Spicy Italian Pizza', 'The Spicy Italian Pizza', 'The Big Meat Pizza']
# Client 139 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Soppressata Pizza', 'The Napolitana Pizza', 'The Greek Pizza', 'The Mediterranean Pizza', 'The Pepper Salami Pizza', 'The Four Cheese Pizza', 'The Italian Supreme Pizza']
# Client 140 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Brie Carre Pizza', 'The California Chicken Pizza']
# Client 141 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Mediterranean Pizza', 'The Barbecue Chicken Pizza', 'The Southwest Chicken Pizza', 'The Barbecue Chicken Pizza']
# Client 142 :
# Recommandations : ['The Chicken Alfredo Pizza']
# Pizzas pertinentes : ['The Classic Deluxe Pizza', 'The Hawaiian Pizza', 'The Sicilian Pizza', 'The Hawaiian Pizza', 'The Sicilian Pizza', 'The Italian Capocollo Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepper Salami Pizza', 'The Chicken Alfredo Pizza']
# Client 143 :
# Recommandations : ['The Four Cheese Pizza']
# Pizzas pertinentes : ['The Four Cheese Pizza']
# Client 144 :
# Recommandations : ['The Italian Vegetables Pizza']
# Pizzas pertinentes : ['The Italian Vegetables Pizza', 'The Italian Vegetables Pizza', 'The Pepper Salami Pizza']
# Client 145 :
# Recommandations : ['The Prosciutto and Arugula Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Pepperoni Pizza', 'The Prosciutto and Arugula Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza']
# Client 146 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Italian Capocollo Pizza', 'The Barbecue Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Chicken Pesto Pizza', 'The Italian Capocollo Pizza', 'The Classic Deluxe Pizza', 'The Chicken Alfredo Pizza']
# Client 147 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Pepperoni, Mushroom, and Peppers Pizza', 'The Vegetables + Vegetables Pizza', 'The Vegetables + Vegetables Pizza']
# Client 148 :
# Recommandations : ['The Chicken Pesto Pizza']
# Pizzas pertinentes : ['The Chicken Pesto Pizza', 'The Classic Deluxe Pizza']
# Client 149 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Thai Chicken Pizza', 'The Southwest Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Italian Capocollo Pizza', 'The Spinach and Feta Pizza', 'The Chicken Pesto Pizza', 'The Mexicana Pizza']
# Client 150 :
# Recommandations : ['The Pepper Salami Pizza']
# Pizzas pertinentes : ['The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni Pizza', 'The Pepper Salami Pizza', 'The Pepperoni Pizza', 'The Classic Deluxe Pizza', 'The Big Meat Pizza']
# Client 151 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Mexicana Pizza', 'The Southwest Chicken Pizza', 'The Thai Chicken Pizza', 'The Barbecue Chicken Pizza', 'The Mexicana Pizza', 'The Mexicana Pizza']
# Client 152 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Brie Carre Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni Pizza', 'The California Chicken Pizza', 'The California Chicken Pizza', 'The Italian Supreme Pizza', 'The Chicken Alfredo Pizza']
# Client 153 :
# Recommandations : ['The Five Cheese Pizza']
# Pizzas pertinentes : ['The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Five Cheese Pizza']
# Client 154 :
# Recommandations : ['The Sicilian Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Soppressata Pizza', 'The Soppressata Pizza', 'The Sicilian Pizza', 'The Sicilian Pizza', 'The Soppressata Pizza']
# Client 155 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Green Garden Pizza', 'The Southwest Chicken Pizza', 'The Calabrese Pizza', 'The Southwest Chicken Pizza']
# Client 156 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Soppressata Pizza', 'The Green Garden Pizza', 'The Soppressata Pizza', 'The Vegetables + Vegetables Pizza']
# Client 157 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Italian Vegetables Pizza', 'The Prosciutto and Arugula Pizza', 'The Soppressata Pizza', 'The Hawaiian Pizza', 'The Italian Vegetables Pizza', 'The Spinach and Feta Pizza', 'The Big Meat Pizza', 'The Chicken Alfredo Pizza']
# Client 158 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Barbecue Chicken Pizza', 'The Italian Supreme Pizza', 'The Spicy Italian Pizza', 'The Pepperoni Pizza', 'The California Chicken Pizza', 'The Italian Supreme Pizza']
# Client 159 :
# Recommandations : ['The Spinach and Feta Pizza']
# Pizzas pertinentes : ['The Spinach and Feta Pizza', 'The Spinach and Feta Pizza', 'The Spinach and Feta Pizza']
# Client 160 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Pepper Salami Pizza', 'The Chicken Pesto Pizza', 'The Five Cheese Pizza', 'The Barbecue Chicken Pizza', 'The Southwest Chicken Pizza']
# Client 161 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Calabrese Pizza', 'The Greek Pizza', 'The Mediterranean Pizza', 'The Mexicana Pizza']
# Client 162 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Spicy Italian Pizza', 'The Italian Capocollo Pizza', 'The Barbecue Chicken Pizza', 'The Pepper Salami Pizza', 'The Calabrese Pizza', 'The Big Meat Pizza', 'The California Chicken Pizza', 'The California Chicken Pizza']
# Client 163 :
# Recommandations : ['The Calabrese Pizza']
# Pizzas pertinentes : ['The Calabrese Pizza', 'The Napolitana Pizza', 'The Hawaiian Pizza', 'The Sicilian Pizza', 'The Thai Chicken Pizza', 'The Pepperoni Pizza', 'The Calabrese Pizza', 'The Pepperoni Pizza', 'The Pepper Salami Pizza']
# Client 164 :
# Recommandations : ['The Chicken Pesto Pizza']
# Pizzas pertinentes : ['The Chicken Pesto Pizza', 'The Soppressata Pizza', 'The Chicken Pesto Pizza']
# Client 165 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Thai Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Barbecue Chicken Pizza', 'The Green Garden Pizza', 'The Five Cheese Pizza', 'The California Chicken Pizza', 'The Barbecue Chicken Pizza']
# Client 166 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Southwest Chicken Pizza', 'The Southwest Chicken Pizza', 'The Greek Pizza', 'The Italian Capocollo Pizza', 'The Italian Supreme Pizza', 'The Spinach Pesto Pizza', 'The Southwest Chicken Pizza', 'The Mexicana Pizza']
# Client 167 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Thai Chicken Pizza', 'The Green Garden Pizza', 'The Pepperoni Pizza', 'The California Chicken Pizza', 'The Italian Supreme Pizza', 'The Four Cheese Pizza']
# Client 168 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Calabrese Pizza', 'The Thai Chicken Pizza', 'The Green Garden Pizza', 'The Prosciutto and Arugula Pizza', 'The Spicy Italian Pizza', 'The Napolitana Pizza', 'The Brie Carre Pizza', 'The Hawaiian Pizza', 'The Mexicana Pizza', 'The Classic Deluxe Pizza', 'The Italian Supreme Pizza', 'The Four Cheese Pizza']
# Client 169 :
# Recommandations : ['The Mediterranean Pizza']
# Pizzas pertinentes : ['The Green Garden Pizza', 'The Prosciutto and Arugula Pizza', 'The Mediterranean Pizza', 'The Prosciutto and Arugula Pizza']
# Client 170 :
# Recommandations : ['The Italian Supreme Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Thai Chicken Pizza', 'The Barbecue Chicken Pizza', 'The Italian Supreme Pizza']
# Client 171 :
# Recommandations : ['The Italian Vegetables Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Italian Vegetables Pizza', 'The Italian Capocollo Pizza']
# Client 172 :
# Recommandations : ['The Spicy Italian Pizza']
# Pizzas pertinentes : ['The Spicy Italian Pizza', 'The Thai Chicken Pizza', 'The Thai Chicken Pizza', 'The Spicy Italian Pizza']
# Client 173 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Vegetables + Vegetables Pizza', 'The Vegetables + Vegetables Pizza', 'The Five Cheese Pizza']
# Client 174 :
# Recommandations : ['The Mediterranean Pizza']
# Pizzas pertinentes : ['The Mediterranean Pizza', 'The Italian Supreme Pizza', 'The Napolitana Pizza', 'The Italian Vegetables Pizza', 'The Prosciutto and Arugula Pizza', 'The Calabrese Pizza', 'The Big Meat Pizza']
# Client 175 :
# Recommandations : ['The Chicken Alfredo Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Chicken Alfredo Pizza', 'The Prosciutto and Arugula Pizza']
# Client 176 :
# Recommandations : ['The Italian Capocollo Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Italian Capocollo Pizza', 'The Barbecue Chicken Pizza', 'The Pepperoni Pizza', 'The Four Cheese Pizza', 'The Pepperoni Pizza', 'The Napolitana Pizza']
# Client 177 :
# Recommandations : ['The Italian Vegetables Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Hawaiian Pizza', 'The Italian Vegetables Pizza', 'The Prosciutto and Arugula Pizza', 'The Spicy Italian Pizza']
# Client 178 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Southwest Chicken Pizza', 'The Spinach Pesto Pizza', 'The Barbecue Chicken Pizza', 'The California Chicken Pizza', 'The Classic Deluxe Pizza', 'The California Chicken Pizza', 'The California Chicken Pizza', 'The Italian Supreme Pizza', 'The Mexicana Pizza']
# Client 179 :
# Recommandations : ['The Brie Carre Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Brie Carre Pizza', 'The Pepperoni Pizza', 'The Spinach and Feta Pizza', 'The Pepperoni Pizza']
# Client 180 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Greek Pizza', 'The Southwest Chicken Pizza', 'The Italian Vegetables Pizza', 'The Chicken Pesto Pizza', 'The Pepperoni Pizza', 'The Napolitana Pizza', 'The Italian Capocollo Pizza', 'The Italian Vegetables Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza', 'The Big Meat Pizza', 'The Chicken Alfredo Pizza']
# Client 181 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Hawaiian Pizza', 'The Hawaiian Pizza', 'The Italian Supreme Pizza', 'The Mexicana Pizza', 'The Classic Deluxe Pizza', 'The California Chicken Pizza']
# Client 182 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Southwest Chicken Pizza', 'The Italian Capocollo Pizza']
# Client 183 :
# Recommandations : ['The Sicilian Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Sicilian Pizza', 'The Thai Chicken Pizza']
# Client 184 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Italian Supreme Pizza', 'The Greek Pizza', 'The Greek Pizza', 'The Pepperoni Pizza', 'The Napolitana Pizza', 'The Thai Chicken Pizza', 'The California Chicken Pizza', 'The Southwest Chicken Pizza']
# Client 185 :
# Recommandations : ['The Four Cheese Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza', 'The Four Cheese Pizza']
# Client 186 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Spinach and Feta Pizza', 'The Pepperoni Pizza', 'The Hawaiian Pizza', 'The Napolitana Pizza', 'The California Chicken Pizza', 'The Green Garden Pizza', 'The Pepperoni Pizza', 'The Four Cheese Pizza', 'The California Chicken Pizza']
# Client 187 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Pepper Salami Pizza', 'The Vegetables + Vegetables Pizza', 'The Spinach and Feta Pizza', 'The Classic Deluxe Pizza', 'The Four Cheese Pizza', 'The Pepperoni Pizza', 'The Big Meat Pizza']
# Client 188 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Southwest Chicken Pizza', 'The California Chicken Pizza', 'The California Chicken Pizza', 'The Southwest Chicken Pizza']
# Client 189 :
# Recommandations : ['The Pepper Salami Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Pepper Salami Pizza', 'The Spinach and Feta Pizza']
# Client 190 :
# Recommandations : ['The Pepper Salami Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Pepper Salami Pizza']
# Client 191 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Thai Chicken Pizza']
# Client 192 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Calabrese Pizza', 'The Greek Pizza', 'The Vegetables + Vegetables Pizza', 'The Napolitana Pizza', 'The Spinach and Feta Pizza', 'The Vegetables + Vegetables Pizza', 'The Italian Capocollo Pizza', 'The Spicy Italian Pizza', 'The Southwest Chicken Pizza']
# Client 193 :
# Recommandations : ['The Italian Vegetables Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Italian Vegetables Pizza', 'The Big Meat Pizza']
# Client 194 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Barbecue Chicken Pizza', 'The California Chicken Pizza']
# Client 195 :
# Recommandations : ['The Calabrese Pizza']
# Pizzas pertinentes : ['The Calabrese Pizza', 'The Chicken Pesto Pizza', 'The Chicken Pesto Pizza', 'The Spicy Italian Pizza', 'The Spicy Italian Pizza']
# Client 196 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Chicken Alfredo Pizza', 'The Soppressata Pizza', 'The Spicy Italian Pizza', 'The Vegetables + Vegetables Pizza', 'The Sicilian Pizza', 'The Pepperoni Pizza', 'The Four Cheese Pizza']
# Client 197 :
# Recommandations : ['The Mediterranean Pizza']
# Pizzas pertinentes : ['The Mediterranean Pizza', 'The Italian Supreme Pizza', 'The Chicken Alfredo Pizza']
# Client 198 :
# Recommandations : ['The Chicken Alfredo Pizza']
# Pizzas pertinentes : ['The Chicken Alfredo Pizza', 'The Chicken Alfredo Pizza', 'The Four Cheese Pizza', 'The Chicken Alfredo Pizza', 'The Four Cheese Pizza']
# Client 199 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Chicken Pesto Pizza', 'The Greek Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Greek Pizza', 'The Greek Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza']
# Client 200 :
# Recommandations : ['The Prosciutto and Arugula Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Pepperoni Pizza', 'The Prosciutto and Arugula Pizza']
# Client 201 :
# Recommandations : ['The Mediterranean Pizza']
# Pizzas pertinentes : ['The Mediterranean Pizza', 'The Soppressata Pizza', 'The Napolitana Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The California Chicken Pizza', 'The Classic Deluxe Pizza']
# Client 202 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Chicken Alfredo Pizza', 'The Spinach Supreme Pizza', 'The Green Garden Pizza', 'The Thai Chicken Pizza', 'The Italian Vegetables Pizza', 'The California Chicken Pizza', 'The Pepperoni Pizza', 'The Big Meat Pizza']
# Client 203 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Pesto Pizza', 'The Thai Chicken Pizza', 'The Pepper Salami Pizza', 'The Five Cheese Pizza', 'The Pepperoni Pizza', 'The Spicy Italian Pizza', 'The Calabrese Pizza']
# Client 204 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Spinach Pesto Pizza', 'The Southwest Chicken Pizza', 'The Spinach and Feta Pizza', 'The Vegetables + Vegetables Pizza', 'The Vegetables + Vegetables Pizza', 'The Vegetables + Vegetables Pizza', 'The Southwest Chicken Pizza']
# Client 205 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Italian Capocollo Pizza', 'The Mexicana Pizza']
# Client 206 :
# Recommandations : ['The Sicilian Pizza']
# Pizzas pertinentes : ['The Italian Supreme Pizza', 'The Sicilian Pizza', 'The Italian Supreme Pizza']
# Client 207 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Southwest Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Prosciutto and Arugula Pizza', 'The Green Garden Pizza', 'The Pepperoni Pizza', 'The Pepper Salami Pizza', 'The Four Cheese Pizza']
# Client 208 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Mexicana Pizza', 'The Southwest Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Mexicana Pizza', 'The Barbecue Chicken Pizza', 'The Chicken Alfredo Pizza']
# Client 209 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Southwest Chicken Pizza', 'The Mexicana Pizza', 'The Spicy Italian Pizza', 'The Pepperoni Pizza', 'The Soppressata Pizza']
# Client 210 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Greek Pizza', 'The Italian Vegetables Pizza', 'The Prosciutto and Arugula Pizza', 'The Napolitana Pizza', 'The Sicilian Pizza', 'The Thai Chicken Pizza', 'The Barbecue Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Five Cheese Pizza', 'The Big Meat Pizza', 'The Barbecue Chicken Pizza', 'The Southwest Chicken Pizza', 'The Chicken Alfredo Pizza', 'The Barbecue Chicken Pizza']
# Client 211 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Southwest Chicken Pizza', 'The Napolitana Pizza', 'The Sicilian Pizza', 'The Thai Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The California Chicken Pizza']
# Client 212 :
# Recommandations : ['The California Chicken Pizza']
# ...
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Soppressata Pizza', 'The Prosciutto and Arugula Pizza', 'The Mexicana Pizza', 'The California Chicken Pizza', 'The Italian Supreme Pizza', 'The Chicken Alfredo Pizza', 'The Four Cheese Pizza']
# Client 6936 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Chicken Alfredo Pizza', 'The Pepperoni Pizza', 'The Barbecue Chicken Pizza', 'The Spinach and Feta Pizza', 'The Five Cheese Pizza', 'The Pepperoni Pizza', 'The Chicken Alfredo Pizza']
# Client 6937 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Southwest Chicken Pizza', 'The Hawaiian Pizza', 'The Sicilian Pizza', 'The Vegetables + Vegetables Pizza', 'The Hawaiian Pizza', 'The Vegetables + Vegetables Pizza', 'The Five Cheese Pizza']
# Client 6938 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Brie Carre Pizza', 'The Five Cheese Pizza', 'The Southwest Chicken Pizza']
# Client 6939 :
# Recommandations : ['The Spinach Pesto Pizza']
# Pizzas pertinentes : ['The Spinach Pesto Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza', 'The Spinach Pesto Pizza']
# Client 6940 :
# Recommandations : ['The Soppressata Pizza']
# Pizzas pertinentes : ['The Soppressata Pizza', 'The Thai Chicken Pizza', 'The Thai Chicken Pizza']
# Client 6941 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Mexicana Pizza', 'The Green Garden Pizza', 'The Mexicana Pizza', 'The Mexicana Pizza']
# Client 6942 :
# Recommandations : ['The Italian Supreme Pizza']
# Pizzas pertinentes : ['The Spicy Italian Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Spicy Italian Pizza', 'The Hawaiian Pizza', 'The Thai Chicken Pizza', 'The Italian Supreme Pizza', 'The Five Cheese Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza']
# Client 6943 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Chicken Pesto Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Greek Pizza', 'The Thai Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Barbecue Chicken Pizza', 'The Pepperoni Pizza', 'The Big Meat Pizza', 'The Southwest Chicken Pizza', 'The Four Cheese Pizza']
# Client 6944 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Mexicana Pizza', 'The Southwest Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Vegetables + Vegetables Pizza', 'The Five Cheese Pizza', 'The Pepperoni Pizza', 'The Barbecue Chicken Pizza', 'The Mexicana Pizza']
# Client 6945 :
# Recommandations : ['The Pepperoni Pizza']
# Pizzas pertinentes : ['The Pepperoni Pizza']
# Client 6946 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Green Garden Pizza', 'The Spicy Italian Pizza', 'The Greek Pizza', 'The Barbecue Chicken Pizza', 'The Spinach and Feta Pizza', 'The Italian Supreme Pizza', 'The Italian Supreme Pizza', 'The Four Cheese Pizza']
# Client 6947 :
# Recommandations : ['The Four Cheese Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Four Cheese Pizza']
# Client 6948 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Spicy Italian Pizza', 'The Calabrese Pizza', 'The Hawaiian Pizza', 'The Thai Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The California Chicken Pizza']
# Client 6949 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Four Cheese Pizza', 'The Southwest Chicken Pizza', 'The Four Cheese Pizza']
# Client 6950 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Italian Capocollo Pizza', 'The Spinach and Feta Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza', 'The California Chicken Pizza']
# Client 6951 :
# Recommandations : ['The Spicy Italian Pizza']
# Pizzas pertinentes : ['The Green Garden Pizza', 'The Spicy Italian Pizza', 'The Spicy Italian Pizza']
# Client 6952 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Napolitana Pizza', 'The Hawaiian Pizza', 'The Sicilian Pizza', 'The California Chicken Pizza', 'The Barbecue Chicken Pizza', 'The Pepper Salami Pizza', 'The Chicken Alfredo Pizza', 'The Napolitana Pizza']
# Client 6953 :
# Recommandations : ['The Napolitana Pizza']
# Pizzas pertinentes : ['The Napolitana Pizza', 'The Napolitana Pizza']
# Client 6954 :
# Recommandations : ['The Pepper Salami Pizza']
# Pizzas pertinentes : ['The Pepper Salami Pizza', 'The Italian Capocollo Pizza', 'The Green Garden Pizza']
# Client 6955 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Vegetables + Vegetables Pizza', 'The Hawaiian Pizza', 'The Vegetables + Vegetables Pizza']
# Client 6956 :
# Recommandations : ['The Soppressata Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Soppressata Pizza']
# Client 6957 :
# Recommandations : ['The Barbecue Chicken Pizza']
# Pizzas pertinentes : ['The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Barbecue Chicken Pizza', 'The Barbecue Chicken Pizza']
# Client 6958 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Spinach Pesto Pizza', 'The Calabrese Pizza', 'The Spinach Pesto Pizza', 'The Greek Pizza', 'The Sicilian Pizza', 'The Thai Chicken Pizza', 'The Barbecue Chicken Pizza', 'The Four Cheese Pizza', 'The Pepperoni Pizza']
# Client 6959 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Napolitana Pizza', 'The Vegetables + Vegetables Pizza', 'The Hawaiian Pizza', 'The Thai Chicken Pizza', 'The Pepper Salami Pizza', 'The Mexicana Pizza', 'The Classic Deluxe Pizza', 'The Four Cheese Pizza', 'The Southwest Chicken Pizza', 'The Four Cheese Pizza', 'The Mexicana Pizza']
# Client 6960 :
# Recommandations : ['The Pepperoni, Mushroom, and Peppers Pizza']
# Pizzas pertinentes : ['The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza']
# Client 6961 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Chicken Pesto Pizza', 'The Sicilian Pizza', 'The Thai Chicken Pizza', 'The Hawaiian Pizza', 'The Italian Capocollo Pizza', 'The Barbecue Chicken Pizza', 'The Five Cheese Pizza', 'The Southwest Chicken Pizza']
# Client 6962 :
# Recommandations : ['The Classic Deluxe Pizza']
# Pizzas pertinentes : ['The Classic Deluxe Pizza', 'The Pepperoni Pizza', 'The Classic Deluxe Pizza', 'The Pepperoni Pizza', 'The Pepperoni Pizza']
# Client 6963 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Italian Vegetables Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Napolitana Pizza', 'The Vegetables + Vegetables Pizza', 'The Italian Vegetables Pizza', 'The Prosciutto and Arugula Pizza', 'The Napolitana Pizza']
# Client 6964 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Napolitana Pizza', 'The Greek Pizza', 'The Five Cheese Pizza']
# Client 6965 :
# Recommandations : ['The Sicilian Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Sicilian Pizza', 'The Sicilian Pizza', 'The Thai Chicken Pizza']
# Client 6966 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Chicken Pesto Pizza', 'The Prosciutto and Arugula Pizza', 'The Spinach Pesto Pizza', 'The Vegetables + Vegetables Pizza', 'The Classic Deluxe Pizza', 'The Spinach Pesto Pizza', 'The California Chicken Pizza']
# Client 6967 :
# Recommandations : ['The Chicken Alfredo Pizza']
# Pizzas pertinentes : ['The Green Garden Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Chicken Alfredo Pizza']
# Client 6968 :
# Recommandations : ['The Italian Vegetables Pizza']
# Pizzas pertinentes : ['The Italian Vegetables Pizza', 'The Pepperoni Pizza', 'The Italian Vegetables Pizza', 'The California Chicken Pizza', 'The Pepperoni Pizza']
# Client 6969 :
# Recommandations : ['The Italian Vegetables Pizza']
# Pizzas pertinentes : ['The Italian Vegetables Pizza', 'The Italian Vegetables Pizza', 'The Napolitana Pizza', 'The Italian Vegetables Pizza']
# Client 6970 :
# Recommandations : ['The Chicken Pesto Pizza']
# Pizzas pertinentes : ['The Chicken Pesto Pizza', 'The Prosciutto and Arugula Pizza', 'The Thai Chicken Pizza', 'The Thai Chicken Pizza', 'The Italian Capocollo Pizza', 'The Five Cheese Pizza', 'The Pepperoni Pizza', 'The Big Meat Pizza']
# Client 6971 :
# Recommandations : ['The Italian Vegetables Pizza']
# Pizzas pertinentes : ['The Italian Vegetables Pizza', 'The Italian Vegetables Pizza', 'The Classic Deluxe Pizza']
# Client 6972 :
# Recommandations : ['The Italian Supreme Pizza']
# Pizzas pertinentes : ['The Italian Supreme Pizza', 'The Five Cheese Pizza']
# Client 6973 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Chicken Alfredo Pizza', 'The Chicken Alfredo Pizza', 'The Classic Deluxe Pizza', 'The Southwest Chicken Pizza', 'The Spinach and Feta Pizza', 'The Thai Chicken Pizza', 'The Vegetables + Vegetables Pizza', 'The Green Garden Pizza', 'The Chicken Pesto Pizza', 'The Big Meat Pizza', 'The Chicken Alfredo Pizza']
# Client 6974 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Soppressata Pizza', 'The Spicy Italian Pizza', 'The Greek Pizza', 'The Sicilian Pizza', 'The Thai Chicken Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Italian Supreme Pizza', 'The Southwest Chicken Pizza', 'The Chicken Alfredo Pizza']
# Client 6975 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Napolitana Pizza', 'The Pepperoni Pizza', 'The Vegetables + Vegetables Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Prosciutto and Arugula Pizza', 'The Spicy Italian Pizza', 'The Pepperoni Pizza', 'The Big Meat Pizza', 'The Southwest Chicken Pizza', 'The Mexicana Pizza']
# Client 6976 :
# Recommandations : ['The Sicilian Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Green Garden Pizza', 'The Sicilian Pizza', 'The Green Garden Pizza']
# Client 6977 :
# Recommandations : ['The Spinach Pesto Pizza']
# Pizzas pertinentes : ['The Spinach Pesto Pizza', 'The Napolitana Pizza', 'The Napolitana Pizza', 'The Soppressata Pizza']
# Client 6978 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Mexicana Pizza', 'The Spinach Supreme Pizza', 'The Green Garden Pizza', 'The Hawaiian Pizza', 'The Vegetables + Vegetables Pizza', 'The Thai Chicken Pizza', 'The Spinach Pesto Pizza', 'The Italian Supreme Pizza', 'The Mexicana Pizza']
# Client 6979 :
# Recommandations : ['The Vegetables + Vegetables Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Vegetables + Vegetables Pizza', 'The Hawaiian Pizza', 'The Thai Chicken Pizza', 'The Italian Supreme Pizza', 'The Italian Capocollo Pizza', 'The Big Meat Pizza', 'The California Chicken Pizza', 'The Barbecue Chicken Pizza']
# Client 6980 :
# Recommandations : ['The Italian Vegetables Pizza']
# Pizzas pertinentes : ['The Italian Vegetables Pizza', 'The Pepperoni Pizza']
# Client 6981 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza', 'The Thai Chicken Pizza', 'The Spinach Supreme Pizza']
# Client 6982 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Southwest Chicken Pizza', 'The Spinach Pesto Pizza', 'The Prosciutto and Arugula Pizza', 'The Pepper Salami Pizza', 'The Chicken Pesto Pizza', 'The Spicy Italian Pizza', 'The Barbecue Chicken Pizza', 'The Pepper Salami Pizza', 'The Barbecue Chicken Pizza']
# Client 6983 :
# Recommandations : ['The Spinach Pesto Pizza']
# Pizzas pertinentes : ['The Spinach Pesto Pizza', 'The Spinach Pesto Pizza', 'The Four Cheese Pizza', 'The Spinach Pesto Pizza']
# Client 6984 :
# Recommandations : ['The California Chicken Pizza']
# Pizzas pertinentes : ['The Spicy Italian Pizza', 'The Napolitana Pizza', 'The Spicy Italian Pizza', 'The California Chicken Pizza']
# Client 6985 :
# Recommandations : ['The Pepperoni, Mushroom, and Peppers Pizza']
# Pizzas pertinentes : ['The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni Pizza']
# Client 6986 :
# Recommandations : ['The Calabrese Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Calabrese Pizza', 'The Greek Pizza', 'The Thai Chicken Pizza']
# Client 6987 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Spinach Supreme Pizza']
# Client 6988 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Mexicana Pizza', 'The Italian Vegetables Pizza', 'The Green Garden Pizza', 'The Italian Capocollo Pizza', 'The Vegetables + Vegetables Pizza', 'The Mediterranean Pizza', 'The Spinach and Feta Pizza', 'The Classic Deluxe Pizza', 'The Spicy Italian Pizza', 'The Pepperoni Pizza', 'The Big Meat Pizza']
# Client 6989 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Sicilian Pizza', 'The California Chicken Pizza', 'The Four Cheese Pizza', 'The Mexicana Pizza']
# Client 6990 :
# Recommandations : ['The Five Cheese Pizza']
# Pizzas pertinentes : ['The Spinach and Feta Pizza', 'The Spinach and Feta Pizza', 'The Five Cheese Pizza']
# Client 6991 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Mexicana Pizza', 'The Southwest Chicken Pizza', 'The Chicken Pesto Pizza', 'The Hawaiian Pizza', 'The Spinach and Feta Pizza', 'The Thai Chicken Pizza', 'The Italian Capocollo Pizza', 'The Calabrese Pizza']
# Client 6992 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Mexicana Pizza', 'The Italian Vegetables Pizza', 'The Greek Pizza', 'The Sicilian Pizza', 'The Sicilian Pizza', 'The Thai Chicken Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni Pizza']
# Client 6993 :
# Recommandations : ['The Spinach Supreme Pizza']
# Pizzas pertinentes : ['The Mediterranean Pizza', 'The Italian Supreme Pizza', 'The Spinach Supreme Pizza', 'The Chicken Pesto Pizza', 'The Pepperoni, Mushroom, and Peppers Pizza', 'The Pepperoni Pizza', 'The Four Cheese Pizza', 'The Big Meat Pizza', 'The California Chicken Pizza']
# Client 6994 :
# Recommandations : ['The Spicy Italian Pizza']
# Pizzas pertinentes : ['The Thai Chicken Pizza', 'The Spicy Italian Pizza', 'The Italian Capocollo Pizza', 'The Thai Chicken Pizza', 'The Italian Capocollo Pizza', 'The Pepperoni Pizza', 'The Spicy Italian Pizza', 'The Soppressata Pizza']
# Client 6995 :
# Recommandations : ['The Chicken Alfredo Pizza']
# Pizzas pertinentes : ['The Four Cheese Pizza', 'The Chicken Alfredo Pizza', 'The Four Cheese Pizza']
# Client 6996 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Italian Vegetables Pizza', 'The Mexicana Pizza', 'The Calabrese Pizza', 'The Barbecue Chicken Pizza', 'The Barbecue Chicken Pizza']
# Client 6997 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Greek Pizza', 'The Spinach Supreme Pizza', 'The Mediterranean Pizza', 'The Five Cheese Pizza', 'The Big Meat Pizza', 'The California Chicken Pizza', 'The Southwest Chicken Pizza', 'The Four Cheese Pizza', 'The Napolitana Pizza']
# Client 6998 :
# Recommandations : ['The Calabrese Pizza']
# Pizzas pertinentes : ['The Sicilian Pizza', 'The Calabrese Pizza', 'The Sicilian Pizza', 'The Sicilian Pizza']
# Client 6999 :
# Recommandations : ['The Hawaiian Pizza']
# Pizzas pertinentes : ['The Hawaiian Pizza', 'The Hawaiian Pizza', 'The Hawaiian Pizza']
# Client 7000 :
# Recommandations : ['The Mexicana Pizza']
# Pizzas pertinentes : ['The Prosciutto and Arugula Pizza', 'The Soppressata Pizza', 'The Prosciutto and Arugula Pizza', 'The Napolitana Pizza', 'The Italian Supreme Pizza', 'The Prosciutto and Arugula Pizza', 'The Mexicana Pizza']
# Précision moyenne : 0.82
# Rappel moyen : 0.30
# F1-Score moyen : 0.41
